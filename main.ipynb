# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# #### Basics - reading a local html file
# This is to pratice bs4 methods

# %%
with open('home.html','r') as html_file:
    content = html_file.read()
    
    soup = BeautifulSoup(content, 'lxml')
    course_cards = soup.find_all('div', class_='card')
    for course in course_cards:
        course_name = course.h5.text
        course_price = course.a.text.split()[-1]
        
        print(f'{course_name} costs {course_price}')
# Out:
# Python for beginners costs 20$
# Python Web Development costs 50$
# Python Machine Learning costs 100$

# %% [markdown]
# ### Get the necessary part of HTML code from the website

# %%
html_text = requests.get('https://m.timesjobs.com/mobile/jobs-search-result.html?txtKeywords=python&cboWorkExp1=-1&txtLocation=').text
soup = BeautifulSoup(html_text,'lxml')

jobs = soup.find_all("li")

# %% [markdown]
# ### Formatting for the needed data

# %% [markdown]
# Version 1 of the code implementation

# %%
posted_period = []
company_names = []
skills_list = []
for job in jobs:
    posting_times = job.find('span',class_='posting-time')
    if posting_times:
        # print(int(posting_times.text[:2]))
        posted_period.append(int(posting_times.text[:2]))
    company_name = job.find('span',class_='srp-comp-name')
    if company_name:
        company_names.append(company_name.text)
    skills = [s.get_text(strip=True) for s in job.find_all('a',class_='srphglt')]
    if skills:    
        skills_list.append(skills)
        
        
# print(len(posted_period))
# print(len(company_names))
# print(len(skills_list))
    

# for company, skills, period in zip(company_names, skills_list, posted_period):
#     if period < 10:
#         print(f"Company: {company}")
#         print(f"Skills: {', '.join(skills)}")
#         print(f"Posted: {period}")
#         print("-" * 30)


df = pd.DataFrame({
    'Company': company_names,
    'Skills': skills_list,
    'Posted': posted_period
})

df['Skills'] = df['Skills'].apply(lambda x: ", ".join(x))
df.head()
# Out:
#                                  Company  \
# 0                       LTIMindtree Ltd.
# 1               Trigyn Technologies Ltd
# 2                       Analytics Vidhya
# 3  magnarus technologies private limited
# 4                       WBC Software Lab
#
#                                               Skills  Posted
# 0                       Solidworks, Python Scripting       7
# 1  python proficiency, web frameworks, api develo...       8
# 2         python, css, html5, html, ajax, javascript       9
# 3  image processing, python, c, c programming, op...       9
# 4  python, git, rest api, linux, mobile, mongodb,...      12

# %% [markdown]
# ### Version 2
# (more optimized)

# %%
data = []
for job in jobs:
    posting_time = job.find('span', class_='posting-time')
    company_name = job.find('span', class_='srp-comp-name')
    skills = job.find_all('a', class_='srphglt')
    
    if posting_time and company_name and skills:
        data.append({
            'Company': company_name.text,
            'Skills': ', '.join(s.get_text(strip=True) for s in skills),
            'Posted': int(posting_time.text[:2])
        })

df = pd.DataFrame(data)
df
# Out:
#                                         Company  \
# 0                              LTIMindtree Ltd.
# 1                      Trigyn Technologies Ltd
# 2                              Analytics Vidhya
# 3         magnarus technologies private limited
# 4                              WBC Software Lab
# 5                                     SYNECHRON
# 6                                INFINITY GROUP
# 7                              LTIMindtree Ltd.
# 8                  Parahit Technologies Limited
# 9                             SEVEN CONSULTANCY
# 10                                        IQVIA
# 11                                      sacumen
# 12                               AxisTechnolabs
# 13                               AxisTechnolabs
# 14                  speqto technologies pvt ltd
# 15                          v support solutions
# 16  pegasus knowledge solutions india pvt ltd.
# 17       PNR Software Solutions Private Limited
# 18                      Wing Global IT Services
# 19                     3RI Technologies Pvt Ltd
# 20                 3Embed Software Technologies
# 21                NLiven Technologies Pvt. Ltd.
# 22                   Bright Vision Technologies
# 23                   Bright Vision Technologies
# 24                   Bright Vision Technologies
#
#                                                Skills  Posted
# 0                        Solidworks, Python Scripting       7
# 1   python proficiency, web frameworks, api develo...       8
# 2          python, css, html5, html, ajax, javascript       9
# 3   image processing, python, c, c programming, op...       9
# 4   python, git, rest api, linux, mobile, mongodb,...      12
# 5   python core programming, data manipulation lib...      19
# 6                python, css, django, html, bootstrap      17
# 7                  Python Developer, Microsoft Office       7
# 8        python, django, json, html, ajax, javascript       2
# 9   rest, python, oracle, sybase, bi, storage, jav...      18
# 10  python programming, aws lambda, ci / cd proces...      18
# 11  html5, sql, docker, elastic search, security, ...      20
# 12  python, django, html5, team player, angularjs,...      20
# 13                 python, django, html5, api, jquery      20
# 14  c, python, github, c, rest api, database, post...      20
# 15  rest, python, natural language processing, dja...      20
# 16  python, css, django, java, html, bootstrap, ap...      20
# 17  python, github, telecom bss, django, devops, l...      20
# 18  spring boot, python, java, django, jpa, hibernate      20
# 19    python, database, security, django, git, mobile      20
# 20  python, django, rest api, operating system, my...      20
# 21  rest, python, html5, javascript, jquery, nosql...       5
# 22  python programming, software development, data...      21
# 23  python programming, software development, data...      21
# 24  python programming, software development, data...      21
