# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# #### Basics - reading a local html file
# This is to pratice bs4 methods

# %%
with open('home.html','r') as html_file:
    content = html_file.read()
    
    soup = BeautifulSoup(content, 'lxml')
    course_cards = soup.find_all('div', class_='card')
    for course in course_cards:
        course_name = course.h5.text
        course_price = course.a.text.split()[-1]
        
        print(f'{course_name} costs {course_price}')
# Out:
# Python for beginners costs 20$
# Python Web Development costs 50$
# Python Machine Learning costs 100$

# %% [markdown]
# ### Get the necessary part of HTML code from the website

# %%
html_text = requests.get('https://m.timesjobs.com/mobile/jobs-search-result.html?txtKeywords=python&cboWorkExp1=-1&txtLocation=').text
soup = BeautifulSoup(html_text,'lxml')

jobs = soup.find_all("li")

# %% [markdown]
# ### Formatting for the needed data

# %% [markdown]
# Version 1 of the code implementation

# %%
posted_period = []
company_names = []
skills_list = []
for job in jobs:
    posting_times = job.find('span',class_='posting-time')
    if posting_times:
        # print(int(posting_times.text[:2]))
        posted_period.append(int(posting_times.text[:2]))
    company_name = job.find('span',class_='srp-comp-name')
    if company_name:
        company_names.append(company_name.text)
    skills = [s.get_text(strip=True) for s in job.find_all('a',class_='srphglt')]
    if skills:    
        skills_list.append(skills)
        
        
# print(len(posted_period))
# print(len(company_names))
# print(len(skills_list))
    

# for company, skills, period in zip(company_names, skills_list, posted_period):
#     if period < 10:
#         print(f"Company: {company}")
#         print(f"Skills: {', '.join(skills)}")
#         print(f"Posted: {period}")
#         print("-" * 30)


df = pd.DataFrame({
    'Company': company_names,
    'Skills': skills_list,
    'Posted': posted_period
})

df['Skills'] = df['Skills'].apply(lambda x: ", ".join(x))
df.head()
# Out:
#              Company                                             Skills  \
# 0  CONNECTING 2 WORK                      rest, python, django, mongodb
# 1  CONNECTING 2 WORK  python, storage, sql, security, database, djan...
# 2  CONNECTING 2 WORK  python, cache, rest api, storage, javascript, ...
# 3  CONNECTING 2 WORK  python, css, github, hosting, bug fixing, boot...
# 4  Techasoft Pvt Ltd  python, javascript, docker, django, postgresql...
#
#    Posted
# 0       1
# 1       1
# 2       1
# 3       1
# 4       2

# %% [markdown]
# ### Version 2
# (more optimized)

# %%
data = []
for job in jobs:
    posting_time = job.find('span', class_='posting-time')
    company_name = job.find('span', class_='srp-comp-name')
    skills = job.find_all('a', class_='srphglt')
    
    if posting_time and company_name and skills:
        data.append({
            'Company': company_name.text,
            'Skills': ', '.join(s.get_text(strip=True) for s in skills),
            'Posted': int(posting_time.text[:2])
        })

df = pd.DataFrame(data)
df
# Out:
#                                               Company  \
# 0                                   CONNECTING 2 WORK
# 1                                   CONNECTING 2 WORK
# 2                                   CONNECTING 2 WORK
# 3                                   CONNECTING 2 WORK
# 4                                   Techasoft Pvt Ltd
# 5                                   SEVEN CONSULTANCY
# 6                                           Excel Ptp
# 7                                 botree technologies
# 8                                      AxisTechnolabs
# 9                              highrise solutions llp
# 10                           3RI Technologies Pvt Ltd
# 11               ADROIT LEARNING AND MANPOWER PVT LTD
# 12                                  SEVEN CONSULTANCY
# 13                              realizer technologies
# 14                                         geekyworks
# 15                  acquiscent technologies pvt. ltd.
# 16  CGI Information Systems and Management Consult...
# 17                          Ctd Techs Private Limited
# 18                               HARMAN INTERNATIONAL
# 19                                           Drawsera
# 20                                  CONNECTING 2 WORK
# 21                                          cloudxlab
# 22                                  CONNECTING 2 WORK
# 23                        FINITE HR CONSUTING PVT LTD
# 24                                  CONNECTING 2 WORK
#
#                                                Skills  Posted
# 0                       rest, python, django, mongodb       1
# 1   python, storage, sql, security, database, djan...       1
# 2   python, cache, rest api, storage, javascript, ...       1
# 3   python, css, github, hosting, bug fixing, boot...       1
# 4   python, javascript, docker, django, postgresql...       2
# 5   Python programming, programming language, fron...       2
# 6   jquery, sql, git, oops, json, mysql, object or...       2
# 7   security compliance, python, html5, svn, javas...       2
# 8   python, css, user interaction, bootstrap, open...       2
# 9   python 3.x, django, linux, mysql, microservice...       2
# 10        python, Pandas, PyQt5, Matplotlib, Openpyxl       2
# 11  rest api, sql, database, security, devops, res...       2
# 12                                   python, mvc, sql       3
# 13    testing, software development life cycle, agile       3
# 14  html5, bootstrap, ajax, git, apache, xml, debu...       3
# 15  python, machine learning, javascript, nosql, j...       3
# 16  python development, application maintenance, q...       3
# 17  html5, storage, artificial intelligence, secur...       1
# 18  python programming, django framework, database...       1
# 19  css, ajax, jquery, sql, database, postgresql, ...       1
# 20  python, css, github, hosting, bug fixing, boot...       1
# 21  css, html5, jquery, git, linux, html, mysql, r...       1
# 22  python, storage, django, testing tools, debugging       1
# 23  python, github, mobile, problem solving, team ...       1
# 24  python, css, bug fixing, bootstrap, javascript...       1

# %%
url = "https://www.amazon.in/s?k=mobile+phone+under+20000&crid=3MZE3X15NFGK6&sprefix=mobile%2Caps%2C345&ref=nb_sb_ss_mvt-t11-ranker_ci_tech-br-left_1_6"

# %%
header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:142.0) Gecko/20100101 Firefox/142.0",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Referer": "https://www.amazon.in/",
    "DNT": "1",
    "Connection": "keep-alive",
}

# %%
webpage = requests.get(url,headers=header)

# %%
print(webpage)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(webpage.content,'html')

# %%
title = soup.find_all('h2',class_="a-size-medium a-spacing-none a-color-base a-text-normal")
prize = soup.find_all('span',class_="a-price-whole")
rating = soup.find_all('span',class_="a-size-small a-color-base")

# %%
print(f'''
Title = {len(title)}      
Prize = {len(prize)}      
Rating = {len(rating)}      
      ''')
# Out:
# Title = 23
# Prize = 28
# Rating = 13

# %%
for heading in title:
    print(heading.text)
# Out:
# Samsung Galaxy M36 5G (Velvet Black, 8 GB RAM, 128 GB Storage)| Circle to Search| Google Gemini| Corning Gorilla Glass Victus+| 7.7mm Slim| AI Enhanced 50 MP OIS Triple Camera| Unmatched Nightography
# iQOO Z10R 5G (Aquamarine, 8GB RAM, 128GB Storage) | 32MP 4K Selfie Camera | Quad-Curved AMOLED Display | Dimensity 7400 Processor with 750K+ AnTuTu
# OnePlus Nord CE4 Lite 5G (Super Silver, 8GB RAM, 128GB Storage) | Lifetime Display Warranty | 5500 mAh Battery, 80W SUPERVOOC and Reverse Charging | 50MP Camera with OIS | 120Hz AMOLED Display
# Samsung Galaxy M35 5G (DayBreak Blue,8GB RAM,128GB Storage)| Corning Gorilla Glass Victus+| AnTuTu Score 595K+| Vapour Cooling Chamber| 6000mAh Battery| 120Hz Super AMOLED Display| AI| Without Charger
# Samsung Galaxy M05 (Mint Green, 4GB RAM, 64 GB Storage) | 50MP Dual Camera | Bigger 6.7" HD+ Display | 5000mAh Battery | 25W Fast Charging | 2 Gen OS Upgrade & 4 Year Security Update | Without Charger
# Motorola G45 5G (Viva Magenta, 8GB RAM, 128GB Storage)
# Samsung Galaxy M06 5G (Blazing Black, 6GB RAM, 128 GB Storage) | MediaTek Dimensity 6300 | AnTuTu Score 422K+ | 12 5G Bands | 25W Fast Charging | 4 Gen of OS Upgrades | Without Charger
# Redmi 13 5G Prime Edition, Hawaiian Blue, 8GB+128GB | India Debut SD 4 Gen 2 AE | 108MP Pro Grade Camera | 6.79in Largest Display in Segment
# Zeno 20 | AI Vana 2.0 | 3GB RAM 64GB ROM | 6.6" HD+ 90Hz Display | 13MP AI Camera | IP54 Rated | Always-On Display | Dynamic Bar | DTS Sound | 5000mAh Battery |3-Year Fluency|Aurora Blue
# Redmi 13 5G Prime Edition, Orchid Pink, 8GB+128GB | India Debut SD 4 Gen 2 AE | 108MP Pro Grade Camera | 6.79in Largest Display in Segment
# iQOO Z10 5G (Glacier Silver, 8GB RAM, 256GB Storage) | India's Biggest Ever 7300 mAh Battery | Snapdragon 7s Gen 3 Processor | Brightest Quad Curved AMOLED Display in The Segment
# Lava Agni 3 5G (Pristine Glass, 8GB+128GB) | India's 1st Dual AMOLED | 1.5K Curved Display | Dimensity 7300X | 50MP Triple AI Telephoto Camera | 66W Fast Charge | with Charging Adapter
# Samsung Galaxy M16 5G (Thunder Black, 6GB RAM, 128 GB Storage) | MediaTek Dimensity 6300 | AnTuTu Score 422K+ | Super Amoled Display | AI | 25W Fast Charging | 6 Gen of OS Upgrades | Without Charger
# Samsung Galaxy M06 5G (Sage Green, 6GB RAM, 128 GB Storage) | MediaTek Dimensity 6300 | AnTuTu Score 422K+ | 12 5G Bands| 25W Fast Charging | 4 Gen of OS Upgrades | Without Charger
# OnePlus Nord CE4 (Dark Chrome, 8GB RAM, 128GB Storage) | Lifetime Display Warranty | Qualcomm® Snapdragon™ 7 Gen 3 - Best in The Segment | 50 MP Camera with OIS
# Samsung Galaxy M06 5G (Sage Green, 4GB RAM, 64GB Storage) | MediaTek Dimensity 6300 | AnTuTu Score 422K+ | 12 5G Bands| 25W Fast Charging | 4 Gen of OS Upgrades | Without Charger
# POCO M6 Plus 5G Graphite Black 8GB RAM 128GB ROM
# Redmi A4 5G (Starry Black, 6GB RAM, 128GB Storage) | Segment Largest 6.88in 120Hz | 50MP Dual Camera | 18W Fast Charging | Charger in The Box
# POCO C71, Cool Blue (6GB, 128GB)
# OnePlus Nord CE4 Lite 5G (Mega Blue, 8GB RAM, 128GB Storage)
# Redmi 15 5G Midnight Black 8GB + 256GB | Segment's Largest 7000mAhA Battery | Segment's Largest Display 17.53cm(6.9) Up to 144Hz | Snapdragon 6s Gen 3 | 18W Reverse Charging | 50MP AI Dual Camera
# Redmi Note 14 5G (Titan Black, 8GB RAM 256GB Storage) | Global Debut MTK Dimensity 7025 Ultra | 2100 nits Segment Brightest 120Hz AMOLED | 50MP Sony LYT 600 OIS+EIS Triple Camera
# Cricut Joy Essential Bundle Includes - Cricut Joy Machine, Joy Smart Vinyl, Joy Insert Cards, Joy Card Mat, 4.5" x 6.25", Joy Starter Tool Set & Joy Transfer Tape - 5.5" x 48
